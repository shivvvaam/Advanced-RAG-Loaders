# %%
from langchain_community.document_loaders.csv_loader import CSVLoader
from pathlib import Path
from pprint import pp

# %%
#define the path to the csv file
csv_file_path = Path("../knowledge-source/organizations.csv")

#check if the file exists
print(f"Does the file exist? {csv_file_path.exists()}")
# Out:
# Does the file exist? True

# %%
#create the csv loader
csv_loader = CSVLoader(file_path=csv_file_path)

# %%
#load the documents
documents = csv_loader.load()

# %%
len(documents)
# Out:
# 1000

# %%
#first 5 rows of the csv file
print(f"First 5 rows of the csv file: {documents[:5]}")
# Out:
# First 5 rows of the csv file: [Document(metadata={'source': '..\\knowledge-source\\organizations.csv', 'row': 0}, page_content='Index: 1\nOrganization Id: E84A904909dF528\nName: Liu-Hoover\nWebsite: http://www.day-hartman.org/\nCountry: Western Sahara\nDescription: Ergonomic zero administration knowledge user\nFounded: 1980\nIndustry: Online Publishing\nNumber of employees: 6852'), Document(metadata={'source': '..\\knowledge-source\\organizations.csv', 'row': 1}, page_content='Index: 2\nOrganization Id: AAC4f9aBF86EAeF\nName: Orr-Armstrong\nWebsite: https://www.chapman.net/\nCountry: Algeria\nDescription: Ergonomic radical budgetary management\nFounded: 1970\nIndustry: Import / Export\nNumber of employees: 7994'), Document(metadata={'source': '..\\knowledge-source\\organizations.csv', 'row': 2}, page_content="Index: 3\nOrganization Id: ad2eb3C8C24DB87\nName: Gill-Lamb\nWebsite: http://lin.com/\nCountry: Cote d'Ivoire\nDescription: Programmable intermediate conglomeration\nFounded: 20
# ...

# %%
print(documents[0].page_content)
# Out:
# Index: 1
# Organization Id: E84A904909dF528
# Name: Liu-Hoover
# Website: http://www.day-hartman.org/
# Country: Western Sahara
# Description: Ergonomic zero administration knowledge user
# Founded: 1980
# Industry: Online Publishing
# Number of employees: 6852

# %%
pp(documents[0].metadata)
# Out:
# {'source': '..\\knowledge-source\\organizations.csv', 'row': 0}
